# %% [markdown]
# # LOS80 Colab Runner
# Run the full restoration pipeline from Google Colab with one click.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q pyyaml

import os
from pathlib import Path

root = Path('/content/drive/MyDrive/LOS80')
root.mkdir(parents=True, exist_ok=True)
os.chdir(root)

# !git clone https://github.com/your-org/los80.git . || true

# !python -m los80.run --config config/config.yaml
